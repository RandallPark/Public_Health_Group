# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file_admit = "data/admissions.csv"
csv_file_dis = "data/discharges.csv"

# %%
admit_data_df = pd.read_csv(csv_file_admit)
admit_data_df.head()
# Out:
#         CASEID  STFIPS (Census state FIPS code)  AGE  SERVICES  SUB1  SUB2  \
# 0  20161483389                                2    6         7     5     7
# 1  20161390991                                2    6         7    11     4
# 2  20161368664                                2    5         7     5    10
# 3  20161332383                                2    6         7     5    10
# 4  20161405955                                2    6         7     2     1
#
#    SUB3  DETCRIM  NOPRIOR  PSOURCE  ...  SEDHPFLG  INHFLG  OTCFLG  OTHERFLG  \
# 0     2        5        1        7  ...         0       0       0         0
# 1     7        6        0        7  ...         0       0       0         0
# 2     2       -9        3        1  ...         0       0       0         0
# 3     4        6        0        7  ...         0       0       0         0
# 4     1        6        4        7  ...         0       0       0         0
#
#    DIVISION  REGION  ALCDRUG  YEAR  CBSA10  IDU
# ...

# %%
dis_data_df = pd.read_csv(csv_file_dis)
dis_data_df.head()
# Out:
#    DISYR       CASEID  STFIPS  AGE  SERVICES  SUB1  SUB2  SUB3  DETCRIM  \
# 0   2016  20161314323       2    6         7     2     1     1       -9
# 1   2016  20161235303       2    5         7     2     1     1       -9
# 2   2016  20161216159       2    4         7     4    10     1       -9
# 3   2016  20161185262       2    4         7    10     4     2       -9
# 4   2016  20161248228       2    5         7     2     1     1       -9
#
#    NOPRIOR  ...  OTCFLG  OTHERFLG  NUMSUBS  IDU  DIVISION  REGION  ALCDRUG  \
# 0        1  ...       0         0        1    0         9       4        1
# 1        1  ...       0         0        1    0         9       4        1
# 2        0  ...       0         0        2    1         9       4        2
# 3        0  ...       0         0        3    1         9       4        3
# 4        1  ...       0         0        1    0         9       4        1
#
#    YEAR  CBSA  GENDER
# 0  2016    -9       2
# 1  2016    -9       2
# ...

# %%
csv_pt_by_state = "data/pt_by_state.csv"
pt_by_state_df = pd.read_csv(csv_pt_by_state)
pt_by_state_df
# Out:
#                        region                 state   value
# 0                     MIDWEST              ILLINOIS   16291
# 1                     MIDWEST               INDIANA   18377
# 2                     MIDWEST                  IOWA   24748
# 3                     MIDWEST                KANSAS   11664
# 4                     MIDWEST              MICHIGAN   56227
# 5                     MIDWEST             MINNESOTA   48542
# 6                     MIDWEST              MISSOURI   48678
# 7                     MIDWEST              NEBRASKA   13107
# 8                     MIDWEST          NORTH DAKOTA    2242
# 9                     MIDWEST                  OHIO     690
# 10                    MIDWEST          SOUTH DAKOTA     176
# 11                    MIDWEST             WISCONSIN      46
# 12                  NORTHEAST           CONNECTICUT   61479
# 13                  NORTHEAST                 MAINE    8379
# 14                  NORTHEAST         MASSACHUSETTS   69237
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
# new_customer_data_df = customer_data_df[['id', 'first_name', 'last_name']].copy()
# new_customer_data_df.head()

# %% [markdown]
# ### Store JSON data into a DataFrame

# %%
json_file = "data/pt_by_state.json"
cases_per_state_df = pd.read_json(json_file)
cases_per_state_df.head()
# Out:
#     region     state  value
# 0  MIDWEST  ILLINOIS  16291
# 1  MIDWEST   INDIANA  18377
# 2  MIDWEST      IOWA  24748
# 3  MIDWEST    KANSAS  11664
# 4  MIDWEST  MICHIGAN  56227

# %% [markdown]
# ### Clean DataFrame

# %%
# new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
# new_customer_location_df.head()

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "root:root@127.0.0.1/patient_treatment_db"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
